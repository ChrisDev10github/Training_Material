# %%
#Characteristics of Businesses
import pandas as pd
import matplotlib.pyplot as plt
import requests
import seaborn as sns

# %%
url = "https://api.census.gov/data/2018/abscb?get=GEO_ID,NAME,NAICS2017,NAICS2017_LABEL,SEX,SEX_LABEL,ETH_GROUP,ETH_GROUP_LABEL,RACE_GROUP,RACE_GROUP_LABEL,VET_GROUP,VET_GROUP_LABEL,QDESC,QDESC_LABEL,BUSCHAR,BUSCHAR_LABEL,YEAR,FIRMPDEMP,FIRMPDEMP_F,FIRMPDEMP_PCT,FIRMPDEMP_PCT_F,RCPPDEMP,RCPPDEMP_F,RCPPDEMP_PCT,RCPPDEMP_PCT_F,EMP,EMP_F,EMP_PCT,EMP_PCT_F,PAYANN,PAYANN_F,PAYANN_PCT,PAYANN_PCT_F,FIRMPDEMP_S,FIRMPDEMP_S_F,FIRMPDEMP_PCT_S,FIRMPDEMP_PCT_S_F,RCPPDEMP_S,RCPPDEMP_S_F,RCPPDEMP_PCT_S,RCPPDEMP_PCT_S_F,EMP_S,EMP_S_F,EMP_PCT_S,EMP_PCT_S_F,PAYANN_S,PAYANN_S_F,PAYANN_PCT_S,PAYANN_PCT_S_F&for=us:*&QDESC_LABEL=SPOUSES&key=b3ba78a4a01bf0ea2af20c82bf42f0e425341ee5"
response = requests.get(url)
print(response.status_code)
# Out:
# 200

# %%
data = response.json()

# %%
cb = pd.DataFrame(data,columns=data.pop(0))

# %%
cb
# Out:
#          GEO_ID           NAME NAICS2017            NAICS2017_LABEL  SEX  \
# 0     0100000US  United States        00      Total for all sectors  001
# 1     0100000US  United States        00      Total for all sectors  001
# 2     0100000US  United States        00      Total for all sectors  001
# 3     0100000US  United States        00      Total for all sectors  001
# 4     0100000US  United States        00      Total for all sectors  001
# ...         ...            ...       ...                        ...  ...
# 8106  0100000US  United States        99  Industries not classified  004
# 8107  0100000US  United States        99  Industries not classified  001
# 8108  0100000US  United States        99  Industries not classified  001
# 8109  0100000US  United States        99  Industries not classified  001
# 8110  0100000US  United States        99  Industries not classified  001
#
#                 SEX_LABEL ETH_GROUP                ETH_GROUP_LABEL RACE_GROUP  \
# 0                   Total       001                          Total         00
# 1                   Total       001                          Total         00
# 2                   Total       001                          Total         00
# 3                   Total       001                          Total         00
# 4                   Total       001                          Total         00
# ...                   ...       ...                            ...        ...
# 8106  Equally male/female       028  Equally Hispanic/non-Hispanic         00
# 8107                Total       029                   Non-Hispanic         00
# 8108                Total       029                   Non-Hispanic         00
# 8109                Total       029                   Non-Hispanic         00
# 8110                Total       029                   Non-Hispanic         00
#
#      RACE_GROUP_LABEL  ... EMP_S EMP_S_F EMP_PCT_S EMP_PCT_S_F PAYANN_S  \
# 0               Total  ...   0.5    None       0.0           X      0.5
# 1               Total  ...   4.8    None       0.5        None      4.3
# 2               Total  ...   8.3    None       0.5        None      5.8
# 3               Total  ...   6.7    None       0.1        None      7.8
# 4               Total  ...   0.8    None       0.9        None      1.7
# ...               ...  ...   ...     ...       ...         ...      ...
# 8106            Total  ...   0.0       D       0.0           D      0.0
# 8107            Total  ...  20.8    None       0.0           X      3.1
# 8108            Total  ...  51.1    None      19.3        None     12.6
# 8109            Total  ...  36.7    None       9.8        None     13.1
# 8110            Total  ...  28.7    None       0.1        None     37.4
#
#      PAYANN_S_F PAYANN_PCT_S PAYANN_PCT_S_F QDESC_LABEL us
# 0          None          0.0              X     SPOUSES  1
# 1          None          0.4           None     SPOUSES  1
# 2          None          0.3           None     SPOUSES  1
# 3          None          0.1           None     SPOUSES  1
# 4          None          0.6           None     SPOUSES  1
# ...         ...          ...            ...         ... ..
# 8106          D          0.0              D     SPOUSES  1
# 8107       None          0.0              X     SPOUSES  1
# 8108       None          2.9           None     SPOUSES  1
# 8109       None          2.1           None     SPOUSES  1
# 8110       None          0.2           None     SPOUSES  1
#
# [8111 rows x 51 columns]

# %%
#Question1
#Number of Hispanic and nonEmployees

cbq1 = cb.rename(columns={"ETH_GROUP_LABEL":"ethnicgrouplab","EMP":"numemployees","SEX_LABEL":"sexlabel","RACE_GROUP_LABEL":"racelabel"})

#Question2 
#Number of Employees by Employer firms

# %%
cbq1
# Out:
#          GEO_ID           NAME NAICS2017            NAICS2017_LABEL  SEX  \
# 0     0100000US  United States        00      Total for all sectors  001
# 1     0100000US  United States        00      Total for all sectors  001
# 2     0100000US  United States        00      Total for all sectors  001
# 3     0100000US  United States        00      Total for all sectors  001
# 4     0100000US  United States        00      Total for all sectors  001
# ...         ...            ...       ...                        ...  ...
# 8106  0100000US  United States        99  Industries not classified  004
# 8107  0100000US  United States        99  Industries not classified  001
# 8108  0100000US  United States        99  Industries not classified  001
# 8109  0100000US  United States        99  Industries not classified  001
# 8110  0100000US  United States        99  Industries not classified  001
#
#                  sexlabel ETH_GROUP                 ethnicgrouplab RACE_GROUP  \
# 0                   Total       001                          Total         00
# 1                   Total       001                          Total         00
# 2                   Total       001                          Total         00
# 3                   Total       001                          Total         00
# 4                   Total       001                          Total         00
# ...                   ...       ...                            ...        ...
# 8106  Equally male/female       028  Equally Hispanic/non-Hispanic         00
# 8107                Total       029                   Non-Hispanic         00
# 8108                Total       029                   Non-Hispanic         00
# 8109                Total       029                   Non-Hispanic         00
# 8110                Total       029                   Non-Hispanic         00
#
#      racelabel  ... EMP_S EMP_S_F EMP_PCT_S EMP_PCT_S_F PAYANN_S PAYANN_S_F  \
# 0        Total  ...   0.5    None       0.0           X      0.5       None
# 1        Total  ...   4.8    None       0.5        None      4.3       None
# 2        Total  ...   8.3    None       0.5        None      5.8       None
# 3        Total  ...   6.7    None       0.1        None      7.8       None
# 4        Total  ...   0.8    None       0.9        None      1.7       None
# ...        ...  ...   ...     ...       ...         ...      ...        ...
# 8106     Total  ...   0.0       D       0.0           D      0.0          D
# 8107     Total  ...  20.8    None       0.0           X      3.1       None
# 8108     Total  ...  51.1    None      19.3        None     12.6       None
# 8109     Total  ...  36.7    None       9.8        None     13.1       None
# 8110     Total  ...  28.7    None       0.1        None     37.4       None
#
#      PAYANN_PCT_S PAYANN_PCT_S_F QDESC_LABEL us
# 0             0.0              X     SPOUSES  1
# 1             0.4           None     SPOUSES  1
# 2             0.3           None     SPOUSES  1
# 3             0.1           None     SPOUSES  1
# 4             0.6           None     SPOUSES  1
# ...           ...            ...         ... ..
# 8106          0.0              D     SPOUSES  1
# 8107          0.0              X     SPOUSES  1
# 8108          2.9           None     SPOUSES  1
# 8109          2.1           None     SPOUSES  1
# 8110          0.2           None     SPOUSES  1
#
# [8111 rows x 51 columns]

# %%
cbq1.columns
# Out:
# Index(['GEO_ID', 'NAME', 'NAICS2017', 'NAICS2017_LABEL', 'SEX', 'sexlabel',
#        'ETH_GROUP', 'ethnicgrouplab', 'RACE_GROUP', 'racelabel', 'VET_GROUP',
#        'VET_GROUP_LABEL', 'QDESC', 'QDESC_LABEL', 'BUSCHAR', 'BUSCHAR_LABEL',
#        'YEAR', 'FIRMPDEMP', 'FIRMPDEMP_F', 'FIRMPDEMP_PCT', 'FIRMPDEMP_PCT_F',
#        'RCPPDEMP', 'RCPPDEMP_F', 'RCPPDEMP_PCT', 'RCPPDEMP_PCT_F',
#        'numemployees', 'EMP_F', 'EMP_PCT', 'EMP_PCT_F', 'PAYANN', 'PAYANN_F',
#        'PAYANN_PCT', 'PAYANN_PCT_F', 'FIRMPDEMP_S', 'FIRMPDEMP_S_F',
#        'FIRMPDEMP_PCT_S', 'FIRMPDEMP_PCT_S_F', 'RCPPDEMP_S', 'RCPPDEMP_S_F',
#        'RCPPDEMP_PCT_S', 'RCPPDEMP_PCT_S_F', 'EMP_S', 'EMP_S_F', 'EMP_PCT_S',
#        'EMP_PCT_S_F', 'PAYANN_S', 'PAYANN_S_F', 'PAYANN_PCT_S',
#        'PAYANN_PCT_S_F', 'QDESC_LABEL', 'us'],
#       dtype='object')

# %%
cbq1.dtypes
# Out:
# GEO_ID               object
# NAME                 object
# NAICS2017            object
# NAICS2017_LABEL      object
# SEX                  object
# sexlabel             object
# ETH_GROUP            object
# ethnicgrouplab       object
# RACE_GROUP           object
# racelabel            object
# VET_GROUP            object
# VET_GROUP_LABEL      object
# QDESC                object
# QDESC_LABEL          object
# BUSCHAR              object
# BUSCHAR_LABEL        object
# YEAR                 object
# FIRMPDEMP            object
# FIRMPDEMP_F          object
# FIRMPDEMP_PCT        object
# FIRMPDEMP_PCT_F      object
# RCPPDEMP             object
# RCPPDEMP_F           object
# RCPPDEMP_PCT         object
# RCPPDEMP_PCT_F       object
# numemployees         object
# EMP_F                object
# EMP_PCT              object
# EMP_PCT_F            object
# PAYANN               object
# PAYANN_F             object
# PAYANN_PCT           object
# PAYANN_PCT_F         object
# FIRMPDEMP_S          object
# FIRMPDEMP_S_F        object
# FIRMPDEMP_PCT_S      object
# FIRMPDEMP_PCT_S_F    object
# RCPPDEMP_S           object
# RCPPDEMP_S_F         object
# RCPPDEMP_PCT_S       object
# RCPPDEMP_PCT_S_F     object
# EMP_S                object
# EMP_S_F              object
# EMP_PCT_S            object
# EMP_PCT_S_F          object
# PAYANN_S             object
# PAYANN_S_F           object
# PAYANN_PCT_S         object
# PAYANN_PCT_S_F       object
# QDESC_LABEL          object
# us                   object
# dtype: object

# %%
cbq1['numemployees']=cbq1['numemployees'].astype(float)

# %%
cbq1.dtypes
# Out:
# GEO_ID                object
# NAME                  object
# NAICS2017             object
# NAICS2017_LABEL       object
# SEX                   object
# sexlabel              object
# ETH_GROUP             object
# ethnicgrouplab        object
# RACE_GROUP            object
# racelabel             object
# VET_GROUP             object
# VET_GROUP_LABEL       object
# QDESC                 object
# QDESC_LABEL           object
# BUSCHAR               object
# BUSCHAR_LABEL         object
# YEAR                  object
# FIRMPDEMP             object
# FIRMPDEMP_F           object
# FIRMPDEMP_PCT         object
# FIRMPDEMP_PCT_F       object
# RCPPDEMP              object
# RCPPDEMP_F            object
# RCPPDEMP_PCT          object
# RCPPDEMP_PCT_F        object
# numemployees         float64
# EMP_F                 object
# EMP_PCT               object
# EMP_PCT_F             object
# PAYANN                object
# PAYANN_F              object
# PAYANN_PCT            object
# PAYANN_PCT_F          object
# FIRMPDEMP_S           object
# FIRMPDEMP_S_F         object
# FIRMPDEMP_PCT_S       object
# FIRMPDEMP_PCT_S_F     object
# RCPPDEMP_S            object
# RCPPDEMP_S_F          object
# RCPPDEMP_PCT_S        object
# RCPPDEMP_PCT_S_F      object
# EMP_S                 object
# EMP_S_F               object
# EMP_PCT_S             object
# EMP_PCT_S_F           object
# PAYANN_S              object
# PAYANN_S_F            object
# PAYANN_PCT_S          object
# PAYANN_PCT_S_F        object
# QDESC_LABEL           object
# us                    object
# dtype: object

# %%
cbq1 = cbq1[['sexlabel','ethnicgrouplab','racelabel','numemployees']]

# %%
cbq1
# Out:
#                  sexlabel                 ethnicgrouplab racelabel  \
# 0                   Total                          Total     Total
# 1                   Total                          Total     Total
# 2                   Total                          Total     Total
# 3                   Total                          Total     Total
# 4                   Total                          Total     Total
# ...                   ...                            ...       ...
# 8106  Equally male/female  Equally Hispanic/non-Hispanic     Total
# 8107                Total                   Non-Hispanic     Total
# 8108                Total                   Non-Hispanic     Total
# 8109                Total                   Non-Hispanic     Total
# 8110                Total                   Non-Hispanic     Total
#
#       numemployees
# 0      128196406.0
# 1        1872957.0
# 2        1260228.0
# 3         359141.0
# 4       17211864.0
# ...            ...
# 8106           0.0
# 8107       79558.0
# 8108        9442.0
# 8109        3588.0
# 8110          57.0
#
# [8111 rows x 4 columns]

# %%
cbh = cbq1[cbq1.ethnicgrouplab!='Equally Hispanic/non-Hispanic']
cbh = cbh[cbq1.ethnicgrouplab!='Unclassifiable']
cbh = cbh[cbq1.ethnicgrouplab!='Classifiable']
#cbh = cbh[cbq1.ethnicgrouplab!='Total']
cbh = cbh[cbq1.sexlabel!='Total']
cbh = cbh[cbq1.sexlabel!='Equally male/female']
cbh
# Out:
# C:\Users\Chris\AppData\Local\Temp/ipykernel_13044/405339675.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   cbh = cbh[cbq1.ethnicgrouplab!='Unclassifiable']
# C:\Users\Chris\AppData\Local\Temp/ipykernel_13044/405339675.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   cbh = cbh[cbq1.ethnicgrouplab!='Classifiable']
# C:\Users\Chris\AppData\Local\Temp/ipykernel_13044/405339675.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   cbh = cbh[cbq1.sexlabel!='Total']
# C:\Users\Chris\AppData\Local\Temp/ipykernel_13044/405339675.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   cbh = cbh[cbq1.sexlabel!='Equally male/female']
#      sexlabel ethnicgrouplab racelabel  numemployees
# 8        Male          Total     Total    45346405.0
# 9        Male          Total     Total      384147.0
# 10       Male          Total     Total      734117.0
# 11       Male          Total     Total       29088.0
# 12       Male          Total     Total    13746415.0
# ...       ...            ...       ...           ...
# 8087   Female       Hispanic     Total           0.0
# 8088     Male       Hispanic     Total        1512.0
# 8089     Male       Hispanic     Total           0.0
# 8090     Male       Hispanic     Total           0.0
# 8091     Male       Hispanic     Total           0.0
#
# [2273 rows x 4 columns]

# %%
cbh=cbh[['ethnicgrouplab','numemployees']]
ree=cbh.groupby(['ethnicgrouplab']).count()

# %%
cbq1['ethnicgrouplab'].unique()
# Out:
# array(['Total', 'Equally Hispanic/non-Hispanic', 'Non-Hispanic',
#        'Hispanic', 'Unclassifiable', 'Classifiable'], dtype=object)

# %%
plt.figure(figsize=(12,14))
sns.set_style("darkgrid")
ax = ree.plot(title = 'Number of Employees that are Hispanic and non-Hispanic',kind='bar')
plt.xlabel('Ethnic Group')
plt.ylabel('Count of Employees')
plt.xticks(rotation=0)
ax.bar_label(ax.containers[0], label_type='edge', fmt='%d');

# %%
#Question 2 
#NAICS with the most employees
cbq2 = cb.rename(columns={"NAICS2017_LABEL":"NAICS","EMP":"emp"})

# %%
cbq2
# Out:
#          GEO_ID           NAME NAICS2017                      NAICS  SEX  \
# 0     0100000US  United States        00      Total for all sectors  001
# 1     0100000US  United States        00      Total for all sectors  001
# 2     0100000US  United States        00      Total for all sectors  001
# 3     0100000US  United States        00      Total for all sectors  001
# 4     0100000US  United States        00      Total for all sectors  001
# ...         ...            ...       ...                        ...  ...
# 8106  0100000US  United States        99  Industries not classified  004
# 8107  0100000US  United States        99  Industries not classified  001
# 8108  0100000US  United States        99  Industries not classified  001
# 8109  0100000US  United States        99  Industries not classified  001
# 8110  0100000US  United States        99  Industries not classified  001
#
#                 SEX_LABEL ETH_GROUP                ETH_GROUP_LABEL RACE_GROUP  \
# 0                   Total       001                          Total         00
# 1                   Total       001                          Total         00
# 2                   Total       001                          Total         00
# 3                   Total       001                          Total         00
# 4                   Total       001                          Total         00
# ...                   ...       ...                            ...        ...
# 8106  Equally male/female       028  Equally Hispanic/non-Hispanic         00
# 8107                Total       029                   Non-Hispanic         00
# 8108                Total       029                   Non-Hispanic         00
# 8109                Total       029                   Non-Hispanic         00
# 8110                Total       029                   Non-Hispanic         00
#
#      RACE_GROUP_LABEL  ... EMP_S EMP_S_F EMP_PCT_S EMP_PCT_S_F PAYANN_S  \
# 0               Total  ...   0.5    None       0.0           X      0.5
# 1               Total  ...   4.8    None       0.5        None      4.3
# 2               Total  ...   8.3    None       0.5        None      5.8
# 3               Total  ...   6.7    None       0.1        None      7.8
# 4               Total  ...   0.8    None       0.9        None      1.7
# ...               ...  ...   ...     ...       ...         ...      ...
# 8106            Total  ...   0.0       D       0.0           D      0.0
# 8107            Total  ...  20.8    None       0.0           X      3.1
# 8108            Total  ...  51.1    None      19.3        None     12.6
# 8109            Total  ...  36.7    None       9.8        None     13.1
# 8110            Total  ...  28.7    None       0.1        None     37.4
#
#      PAYANN_S_F PAYANN_PCT_S PAYANN_PCT_S_F QDESC_LABEL us
# 0          None          0.0              X     SPOUSES  1
# 1          None          0.4           None     SPOUSES  1
# 2          None          0.3           None     SPOUSES  1
# 3          None          0.1           None     SPOUSES  1
# 4          None          0.6           None     SPOUSES  1
# ...         ...          ...            ...         ... ..
# 8106          D          0.0              D     SPOUSES  1
# 8107       None          0.0              X     SPOUSES  1
# 8108       None          2.9           None     SPOUSES  1
# 8109       None          2.1           None     SPOUSES  1
# 8110       None          0.2           None     SPOUSES  1
#
# [8111 rows x 51 columns]

# %%
cbq2['NAICS'].unique()
# Out:
# array(['Total for all sectors',
#        'Agriculture, forestry, fishing and hunting',
#        'Mining, quarrying, and oil and gas extraction', 'Utilities',
#        'Construction', 'Manufacturing', 'Wholesale trade',
#        'Transportation and warehousing', 'Retail trade', 'Information',
#        'Finance and insurance', 'Real estate and rental and leasing',
#        'Professional, scientific, and technical services',
#        'Management of companies and enterprises',
#        'Administrative and support and waste management and remediation services',
#        'Health care and social assistance', 'Educational services',
#        'Arts, entertainment, and recreation', 'Industries not classified',
#        'Accommodation and food services',
#        'Other services (except public administration)'], dtype=object)

# %%
cbq2 = cbq2[['NAICS','emp']]
topcbq2 = cbq2[cbq2.NAICS!='Total for all sectors']
topcbq2 = topcbq2[cbq2.NAICS!='Industries not classified']
ree2=topcbq2.groupby(['NAICS']).count()
ree2
# Out:
# C:\Users\Chris\AppData\Local\Temp/ipykernel_13044/945764348.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   topcbq2 = topcbq2[cbq2.NAICS!='Industries not classified']
#                                                     emp
# NAICS
# Accommodation and food services                     408
# Administrative and support and waste management...  402
# Agriculture, forestry, fishing and hunting          279
# Arts, entertainment, and recreation                 356
# Construction                                        391
# Educational services                                366
# Finance and insurance                               379
# Health care and social assistance                   413
# Information                                         396
# Management of companies and enterprises             280
# Manufacturing                                       418
# Mining, quarrying, and oil and gas extraction       318
# Other services (except public administration)       403
# Professional, scientific, and technical services    424
# Real estate and rental and leasing                  404
# Retail trade                                        419
# Transportation and warehousing                      394
# Utilities                                           274
# Wholesale trade                                     407

# %%
ax2 = ree2.plot(title = 'NUMBER OF EMPLOYEES BY NAICS',kind='barh')
plt.xlabel('Number of Employees')
plt.ylabel('NAICS')
ax2.get_legend().remove()


plt.xticks(rotation=0);

# %%
#Question 3
#Is there a relationship between the number of employees and the number of owners

# %%
#Load characteristics of business
url2 = 'https://api.census.gov/data/2018/abscbo?get=GEO_ID,NAME,NAICS2017,NAICS2017_LABEL,OWNER_SEX,OWNER_SEX_LABEL,OWNER_ETH,OWNER_ETH_LABEL,OWNER_RACE,OWNER_RACE_LABEL,OWNER_VET,OWNER_VET_LABEL,QDESC,QDESC_LABEL,OWNCHAR,OWNCHAR_LABEL,YEAR,OWNPDEMP,OWNPDEMP_F,OWNPDEMP_PCT,OWNPDEMP_PCT_F,OWNPDEMP_S,OWNPDEMP_S_F,OWNPDEMP_PCT_S,OWNPDEMP_PCT_S_F&for=us:*&QDESC_LABEL=YRACQBUS&key=b3ba78a4a01bf0ea2af20c82bf42f0e425341ee5'
response2 = requests.get(url2)
data2 = response2.json()
cbo = pd.DataFrame(data2,columns=data2.pop(0))

# %%
cbo
# Out:
#          GEO_ID           NAME NAICS2017            NAICS2017_LABEL OWNER_SEX  \
# 0     0100000US  United States        00      Total for all sectors       001
# 1     0100000US  United States        00      Total for all sectors       001
# 2     0100000US  United States        00      Total for all sectors       001
# 3     0100000US  United States        00      Total for all sectors       001
# 4     0100000US  United States        00      Total for all sectors       001
# ...         ...            ...       ...                        ...       ...
# 9663  0100000US  United States        99  Industries not classified       001
# 9664  0100000US  United States        99  Industries not classified       002
# 9665  0100000US  United States        99  Industries not classified       002
# 9666  0100000US  United States        99  Industries not classified       002
# 9667  0100000US  United States        99  Industries not classified       002
#
#                      OWNER_SEX_LABEL OWNER_ETH  \
# 0     All owners of respondent firms       001
# 1     All owners of respondent firms       001
# 2     All owners of respondent firms       001
# 3     All owners of respondent firms       001
# 4     All owners of respondent firms       001
# ...                              ...       ...
# 9663  All owners of respondent firms       001
# 9664                          Female       001
# 9665                          Female       001
# 9666                          Female       001
# 9667                          Female       001
#
#                      OWNER_ETH_LABEL OWNER_RACE           OWNER_RACE_LABEL  \
# 0     All owners of respondent firms         40  Black or African American
# 1     All owners of respondent firms         40  Black or African American
# 2     All owners of respondent firms         40  Black or African American
# 3     All owners of respondent firms         40  Black or African American
# 4     All owners of respondent firms         40  Black or African American
# ...                              ...        ...                        ...
# 9663  All owners of respondent firms         30                      White
# 9664  All owners of respondent firms         30                      White
# 9665  All owners of respondent firms         30                      White
# 9666  All owners of respondent firms         30                      White
# 9667  All owners of respondent firms         30                      White
#
#       ... OWNPDEMP OWNPDEMP_F OWNPDEMP_PCT OWNPDEMP_PCT_F OWNPDEMP_S  \
# 0     ...    21939       None         29.9           None        5.1
# 1     ...      912       None          1.2           None       20.3
# 2     ...     7441       None         10.1           None        4.2
# 3     ...    73427       None        100.0           None        2.1
# 4     ...     3106       None          0.0              X        5.2
# ...   ...      ...        ...          ...            ...        ...
# 9663  ...      290       None          0.0              X       14.2
# 9664  ...      909       None         24.2           None       12.2
# 9665  ...     1000       None         26.6           None       12.5
# 9666  ...      594       None         15.8           None       18.7
# 9667  ...      230       None          6.1           None       20.7
#
#      OWNPDEMP_S_F OWNPDEMP_PCT_S OWNPDEMP_PCT_S_F QDESC_LABEL us
# 0            None            1.2             None    YRACQBUS  1
# 1            None            0.3             None    YRACQBUS  1
# 2            None            0.5             None    YRACQBUS  1
# 3            None            0.0             None    YRACQBUS  1
# 4            None            0.0                X    YRACQBUS  1
# ...           ...            ...              ...         ... ..
# 9663         None            0.0                X    YRACQBUS  1
# 9664         None            2.3             None    YRACQBUS  1
# 9665         None            2.9             None    YRACQBUS  1
# 9666         None            3.2             None    YRACQBUS  1
# 9667         None            1.3             None    YRACQBUS  1
#
# [9668 rows x 27 columns]

# %%
merged = cb.merge(cbo,how='inner',on='NAICS2017')

# %%
merged
# Out:
#           GEO_ID_x         NAME_x NAICS2017  \
# 0        0100000US  United States        00
# 1        0100000US  United States        00
# 2        0100000US  United States        00
# 3        0100000US  United States        00
# 4        0100000US  United States        00
# ...            ...            ...       ...
# 3811133  0100000US  United States        81
# 3811134  0100000US  United States        81
# 3811135  0100000US  United States        81
# 3811136  0100000US  United States        81
# 3811137  0100000US  United States        81
#
#                                      NAICS2017_LABEL_x  SEX SEX_LABEL  \
# 0                                Total for all sectors  001     Total
# 1                                Total for all sectors  001     Total
# 2                                Total for all sectors  001     Total
# 3                                Total for all sectors  001     Total
# 4                                Total for all sectors  001     Total
# ...                                                ...  ...       ...
# 3811133  Other services (except public administration)  003      Male
# 3811134  Other services (except public administration)  003      Male
# 3811135  Other services (except public administration)  003      Male
# 3811136  Other services (except public administration)  003      Male
# 3811137  Other services (except public administration)  003      Male
#
#         ETH_GROUP ETH_GROUP_LABEL RACE_GROUP RACE_GROUP_LABEL  ... OWNPDEMP  \
# 0             001           Total         00            Total  ...    21939
# 1             001           Total         00            Total  ...      912
# 2             001           Total         00            Total  ...     7441
# 3             001           Total         00            Total  ...    73427
# 4             001           Total         00            Total  ...     3106
# ...           ...             ...        ...              ...  ...      ...
# 3811133       001           Total         92      Nonminority  ...       64
# 3811134       001           Total         92      Nonminority  ...        0
# 3811135       001           Total         92      Nonminority  ...       47
# 3811136       001           Total         92      Nonminority  ...        0
# 3811137       001           Total         92      Nonminority  ...        0
#
#         OWNPDEMP_F OWNPDEMP_PCT OWNPDEMP_PCT_F OWNPDEMP_S OWNPDEMP_S_F  \
# 0             None         29.9           None        5.1         None
# 1             None          1.2           None       20.3         None
# 2             None         10.1           None        4.2         None
# 3             None        100.0           None        2.1         None
# 4             None          0.0              X        5.2         None
# ...            ...          ...            ...        ...          ...
# 3811133       None         36.2           None       65.8         None
# 3811134          D          0.0              D        0.0            D
# 3811135       None         26.6           None       65.0         None
# 3811136          D          0.0              D        0.0            D
# 3811137          D          0.0              D        0.0            D
#
#         OWNPDEMP_PCT_S OWNPDEMP_PCT_S_F QDESC_LABEL_y us_y
# 0                  1.2             None      YRACQBUS    1
# 1                  0.3             None      YRACQBUS    1
# 2                  0.5             None      YRACQBUS    1
# 3                  0.0             None      YRACQBUS    1
# 4                  0.0                X      YRACQBUS    1
# ...                ...              ...           ...  ...
# 3811133           17.4             None      YRACQBUS    1
# 3811134            0.0                D      YRACQBUS    1
# 3811135           23.0             None      YRACQBUS    1
# 3811136            0.0                D      YRACQBUS    1
# 3811137            0.0                D      YRACQBUS    1
#
# [3811138 rows x 77 columns]

# %%
merged.columns
# Out:
# Index(['GEO_ID_x', 'NAME_x', 'NAICS2017', 'NAICS2017_LABEL_x', 'SEX',
#        'SEX_LABEL', 'ETH_GROUP', 'ETH_GROUP_LABEL', 'RACE_GROUP',
#        'RACE_GROUP_LABEL', 'VET_GROUP', 'VET_GROUP_LABEL', 'QDESC_x',
#        'QDESC_LABEL_x', 'BUSCHAR', 'BUSCHAR_LABEL', 'YEAR_x', 'FIRMPDEMP',
#        'FIRMPDEMP_F', 'FIRMPDEMP_PCT', 'FIRMPDEMP_PCT_F', 'RCPPDEMP',
#        'RCPPDEMP_F', 'RCPPDEMP_PCT', 'RCPPDEMP_PCT_F', 'EMP', 'EMP_F',
#        'EMP_PCT', 'EMP_PCT_F', 'PAYANN', 'PAYANN_F', 'PAYANN_PCT',
#        'PAYANN_PCT_F', 'FIRMPDEMP_S', 'FIRMPDEMP_S_F', 'FIRMPDEMP_PCT_S',
#        'FIRMPDEMP_PCT_S_F', 'RCPPDEMP_S', 'RCPPDEMP_S_F', 'RCPPDEMP_PCT_S',
#        'RCPPDEMP_PCT_S_F', 'EMP_S', 'EMP_S_F', 'EMP_PCT_S', 'EMP_PCT_S_F',
#        'PAYANN_S', 'PAYANN_S_F', 'PAYANN_PCT_S', 'PAYANN_PCT_S_F',
#        'QDESC_LABEL_x', 'us_x', 'GEO_ID_y', 'NAME_y', 'NAICS2017_LABEL_y',
#        'OWNER_SEX', 'OWNER_SEX_LABEL', 'OWNER_ETH', 'OWNER_ETH_LABEL',
#        'OWNER_RACE', 'OWNER_RACE_LABEL', 'OWNER_VET', 'OWNER_VET_LABEL',
#        'QDESC_y', 'QDESC_LABEL_y', 'OWNCHAR', 'OWNCHAR_LABEL', 'YEAR_y',
#        'OWNPDEMP', 'OWNPDEMP_F', 'OWNPDEMP_PCT', 'OWNPDEMP_PCT_F',
#        'OWNPDEMP_S', 'OWNPDEMP_S_F', 'OWNPDEMP_PCT_S', 'OWNPDEMP_PCT_S_F',
#        'QDESC_LABEL_y', 'us_y'],
#       dtype='object')

# %%
merged['RACE_GROUP_LABEL'].unique()
# Out:
# array(['Total', 'White', 'American Indian and Alaska Native',
#        'Black or African American', 'Asian',
#        'Native Hawaiian and Other Pacific Islander', 'Minority',
#        'Equally minority/nonminority', 'Nonminority', 'Unclassifiable',
#        'Classifiable'], dtype=object)

# %%
merged['OWNER_RACE_LABEL']
# Out:
# NAICS2017_LABEL_x
# Accommodation and food services                                             1
# Administrative and support and waste management and remediation services    1
# Agriculture, forestry, fishing and hunting                                  1
# Arts, entertainment, and recreation                                         1
# Construction                                                                1
# Educational services                                                        1
# Finance and insurance                                                       1
# Health care and social assistance                                           1
# Industries not classified                                                   1
# Information                                                                 1
# Management of companies and enterprises                                     1
# Manufacturing                                                               1
# Mining, quarrying, and oil and gas extraction                               1
# Other services (except public administration)                               1
# Professional, scientific, and technical services                            1
# Real estate and rental and leasing                                          1
# Retail trade                                                                1
# Total for all sectors                                                       1
# Transportation and warehousing                                              1
# Utilities                                                                   1
# Wholesale trade                                                             1
# Name: OWNER_RACE_LABEL, dtype: int64

# %%
merged['EMP']=merged['EMP'].astype(float)
merged['OWNPDEMP']=merged['OWNPDEMP'].astype(float)
merged=merged.groupby(['NAICS2017_LABEL_x']).count()



sns.set_theme(style="darkgrid")
plt.figure(figsize = (20,10))
plt.title('Number of Employees vs Number of Owners', size=22)
sns.scatterplot(x='OWNPDEMP',
                y='EMP',
                data=merged,
                s=300,
                color='red',
               alpha=0.2,
               edgecolor='black')
plt.ylim([0,250000])
plt.xlim([0,250000])
# Out:
# (0.0, 250000.0)
