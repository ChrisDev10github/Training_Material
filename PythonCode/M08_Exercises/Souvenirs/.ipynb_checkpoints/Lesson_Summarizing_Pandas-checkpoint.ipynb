# %%
import pandas as pd
souvenirs = pd.read_csv('souvenir.csv')
categories = pd.read_csv('category.csv')
owners = pd.read_csv('owner.csv')

# Merge data and clean up the table
souvenirs = souvenirs[['ItemID','Price','Weight','OwnerID','CategoryID','Name']]

souvenirs_with_categories = souvenirs.merge(categories,how='inner',on='CategoryID')
souvenirs_with_categories.rename(columns={"Name_x":"SouvenirName","Name_y":"CategoryName"},inplace=True)
souvenirs_with_categories_with_owners = souvenirs_with_categories.merge(owners,how='inner',on='OwnerID')
souvenirs_with_categories_with_owners.rename(columns={"Name":"OwnerName"},inplace=True)
souvenirs_with_categories_with_owners.drop(['OwnerID','CategoryID'],inplace=True,axis=1)

# %%
souvenirs_with_categories_with_owners[['Price','Weight']].describe()
# Out:
#               Price        Weight
# count  1.470000e+02    109.000000
# mean   1.226800e+04    171.754679
# std    1.484596e+05   1688.389720
# min    0.000000e+00      0.750000
# 25%    0.000000e+00      4.000000
# 50%    2.990000e+00      6.000000
# 75%    1.624000e+01     16.000000
# max    1.800000e+06  17637.000000

# %%
#Aggregates

souvenirs_with_categories_with_owners.agg({'Price':['min','max','median','sum'],'Weight':['min','max','median']})
# Out:
#              Price    Weight
# min           0.00      0.75
# max     1800000.00  17637.00
# median        2.99      6.00
# sum     1803395.65       NaN

# %%
souvenirs_with_categories_with_owners.groupby('CategoryName')['Price'].sum()
# Out:
# CategoryName
# Art                  155.98
# Artifact         1800041.16
# Book                 197.08
# Clothing             485.94
# Food                  22.95
# Geological            18.99
# Kitchenware          481.61
# Miscellaneous       1949.44
# Postcard              21.70
# Tool                   0.00
# Toy                   20.80
# Name: Price, dtype: float64

# %%
#average

souvenirs_with_categories_with_owners.groupby('CategoryName')['Price'].median()
# Out:
# CategoryName
# Art              12.500
# Artifact          0.000
# Book             16.490
# Clothing         17.495
# Food             22.950
# Geological        0.000
# Kitchenware      12.290
# Miscellaneous     1.000
# Postcard          1.225
# Tool              0.000
# Toy               0.000
# Name: Price, dtype: float64

# %%
souvenirs_with_categories_with_owners.groupby('CategoryName')['Price'].describe()
# Out:
#                count           mean            std    min      25%     50%  \
# CategoryName
# Art             10.0      15.598000      14.575871   0.00   2.4975  12.500
# Artifact        10.0  180004.116000  569208.532762   0.00   0.0000   0.000
# Book             9.0      21.897778      14.230154   1.34  15.6000  16.490
# Clothing        16.0      30.371250      33.407899   0.00   0.0000  17.495
# Food             1.0      22.950000            NaN  22.95  22.9500  22.950
# Geological      30.0       0.633000       3.467084   0.00   0.0000   0.000
# Kitchenware     35.0      13.760286       8.582943   0.00   9.8500  12.290
# Miscellaneous   16.0     121.840000     405.925566   0.00   0.0000   1.000
# Postcard        12.0       1.808333       1.661110   0.00   0.9425   1.225
# Tool             3.0       0.000000       0.000000   0.00   0.0000   0.000
# Toy              5.0       4.160000       9.302043   0.00   0.0000   0.000
#
#                    75%         max
# CategoryName
# Art            23.7500       40.00
# Artifact        0.0000  1800000.00
# Book           29.9900       49.99
# Clothing       46.2475      120.00
# Food           22.9500       22.95
# Geological      0.0000       18.99
# Kitchenware    14.9950       50.00
# Miscellaneous  46.6250     1640.00
# Postcard        2.6225        5.99
# Tool            0.0000        0.00
# Toy             0.0000       20.80

# %%
#groupby multiple categories


souvenirs_with_categories_with_owners.groupby(['CategoryName','OwnerName'])['Price'].median()
# Out:
# CategoryName   OwnerName
# Art            Group 1          20.000
#                Group 4           0.000
# Artifact       Group 1      900020.580
#                Group 4           0.000
# Book           Group 2          16.490
# Clothing       Group 1          19.990
#                Group 2          43.500
#                Group 4           0.000
# Food           Group 1          22.950
# Geological     Group 2           0.000
#                Group 4           0.000
#                Group 5           0.000
# Kitchenware    Group 1           8.950
#                Group 2          16.490
#                Group 3          11.695
#                Group 4           0.000
# Miscellaneous  Group 1          25.975
#                Group 2          22.750
#                Group 4           0.000
# Postcard       Group 2           1.620
#                Group 4           0.000
# Tool           Group 4           0.000
# Toy            Group 1          20.800
#                Group 4           0.000
# Name: Price, dtype: float64

# %%
#Aggregating string values

souvenirs_with_categories_with_owners.groupby(['OwnerName','CategoryName']).agg({'SouvenirName':list})
# Out:
#                                                               SouvenirName
# OwnerName CategoryName
# Group 1   Art            [Crafts Enameled Cockatoo, Hand Painted Rose F...
#           Artifact       [Vintage Maori Carving Intricate Patu Club & L...
#           Clothing       [Tenugui Cotton Cloth Rice Grains, Alpaca Ponc...
#           Food                                       [Organic Maple Syrup]
#           Kitchenware                                         [Shot Glass]
#           Miscellaneous  [Resort Snowglobe, Iron Standing Dog, Cast Iro...
#           Toy                 [12'' Ancient Traditional Korea Hanbok Doll]
# Group 2   Book           [Hand-bound sketchbook, Ink Artbook, Manga, Mo...
#           Clothing       [Fancy Scarf, Sari, Blouse, Sunglasses, Headsc...
#           Geological                   [Smooth Rock, Black Rock, Obsidian]
#           Kitchenware    [Mickey Mouse Shotglass, Gold Spoon, Eiffel To...
#           Miscellaneous  [Red scallop shell, Egyptian Drum, Shiny Shell...
#           Postcard       [City postcard, Sunset Postcard, Petronas Towe...
# Group 3   Kitchenware    [Grizzly Bear Mug, Snowy Mountain Mug, Lobster...
# Group 4   Art                         [The Last Supper, Mona Lisa, Sphinx]
#           Artifact       [Rian Johnson's Creativity, Replica George Was...
#           Clothing       [PCB T-Shirt, Daytona 500 Hat, Swim Suit, Anci...
#           Geological     [Quartz rock, Diamonds, Emerald, Topaz, Ruby, ...
#           Kitchenware    [I Got Tipsy In Key West shot glass, Gordon Ra...
#           Miscellaneous  [NYC bronze ornament, 9/11 bronze ornament, Ta...
#           Postcard         [Eiffle Tower Postcard, Mount Everest Postcard]
#           Tool              [Texas Pen, Panda Pencil Holder, Skeleton Key]
#           Toy            [Super Soaker, Oxygen Not Included, Stardew Va...
# Group 5   Geological     [Central Park-dirt, Hollywood Bowl-dirt, Burha...

# %%
#Functions   AND ADD NEW COLUMNS

bills = souvenirs_with_categories_with_owners[['OwnerName','CategoryName','Price']]

def calc_tips_10percent(x):
    return (x * .1)

bills['tip'] = bills.Price.apply(calc_tips_10percent)
bills['final_total'] = bills['Price'] + bills['tip']
bills.head()
# Out:
# C:\Users\Chris\AppData\Local\Temp/ipykernel_10884/2902766760.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bills['tip'] = bills.Price.apply(calc_tips_10percent)
# C:\Users\Chris\AppData\Local\Temp/ipykernel_10884/2902766760.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bills['final_total'] = bills['Price'] + bills['tip']
#   OwnerName CategoryName  Price    tip  final_total
# 0   Group 3  Kitchenware   7.50  0.750        8.250
# 1   Group 3  Kitchenware   9.99  0.999       10.989
# 2   Group 3  Kitchenware  12.99  1.299       14.289
# 3   Group 3  Kitchenware  10.25  1.025       11.275
# 4   Group 3  Kitchenware   6.91  0.691        7.601

# %%
# Function with parameter

bills = souvenirs_with_categories_with_owners[['OwnerName','CategoryName','Price']]
bills.head()

def calc_tips_percent(total,percentage):
    return (total * percentage/100)

bills['tip'] = bills.Price.apply(calc_tips_percent,percentage=10)
bills['final_total'] = bills['Price'] + bills['tip']
bills.head()
# Out:
# C:\Users\Chris\AppData\Local\Temp/ipykernel_10884/3126766755.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bills['tip'] = bills.Price.apply(calc_tips_percent,percentage=10)
# C:\Users\Chris\AppData\Local\Temp/ipykernel_10884/3126766755.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bills['final_total'] = bills['Price'] + bills['tip']
#   OwnerName CategoryName  Price    tip  final_total
# 0   Group 3  Kitchenware   7.50  0.750        8.250
# 1   Group 3  Kitchenware   9.99  0.999       10.989
# 2   Group 3  Kitchenware  12.99  1.299       14.289
# 3   Group 3  Kitchenware  10.25  1.025       11.275
# 4   Group 3  Kitchenware   6.91  0.691        7.601

# %%
bills = souvenirs_with_categories_with_owners[['OwnerName','CategoryName','Price']]
bills.head()

def calc_tips_percent(total,percentage):
    return (total * percentage/100)

bills['tip'] = bills.Price.apply(calc_tips_percent,percentage=25)
bills['final_total'] = bills['Price'] + bills['tip']
bills.head()
# Out:
# C:\Users\Chris\AppData\Local\Temp/ipykernel_10884/944881645.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bills['tip'] = bills.Price.apply(calc_tips_percent,percentage=25)
# C:\Users\Chris\AppData\Local\Temp/ipykernel_10884/944881645.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bills['final_total'] = bills['Price'] + bills['tip']
#   OwnerName CategoryName  Price     tip  final_total
# 0   Group 3  Kitchenware   7.50  1.8750       9.3750
# 1   Group 3  Kitchenware   9.99  2.4975      12.4875
# 2   Group 3  Kitchenware  12.99  3.2475      16.2375
# 3   Group 3  Kitchenware  10.25  2.5625      12.8125
# 4   Group 3  Kitchenware   6.91  1.7275       8.6375
