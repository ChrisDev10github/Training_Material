# %%
import pandas as pd
import matplotlib.pyplot as plt
import requests

# %%
urlcb = "https://api.census.gov/data/2018/abscb?get=NAME,GEO_ID,NAICS2017_LABEL,SEX,ETH_GROUP,RACE_GROUP,VET_GROUP,FIRMPDEMP&for=us:*&NAICS2017=00&BUSCHAR=A1&QDESC=B01&key=b3ba78a4a01bf0ea2af20c82bf42f0e425341ee5"
responsecb = requests.get(urlcb)

# %%
responsecb
# Out:
# <Response [200]>

# %%
cbjson = responsecb.json()

# %%
cbdf = pd.DataFrame(cbjson,columns=cbjson.pop(0))

# %%
cbdf
# Out:
#              NAME     GEO_ID        NAICS2017_LABEL  SEX ETH_GROUP RACE_GROUP  \
# 0   United States  0100000US  Total for all sectors  001       001         00
# 1   United States  0100000US  Total for all sectors  002       001         00
# 2   United States  0100000US  Total for all sectors  003       001         00
# 3   United States  0100000US  Total for all sectors  004       001         00
# 4   United States  0100000US  Total for all sectors  001       020         00
# ..            ...        ...                    ...  ...       ...        ...
# 90  United States  0100000US  Total for all sectors  001       001         00
# 91  United States  0100000US  Total for all sectors  002       001         00
# 92  United States  0100000US  Total for all sectors  003       001         00
# 93  United States  0100000US  Total for all sectors  004       001         00
# 94  United States  0100000US  Total for all sectors  001       020         00
#
# ...

# %%
urlcs = 'https://api.census.gov/data/2018/abscs?get=NAME,GEO_ID,NAICS2017_LABEL,SEX,ETH_GROUP,RACE_GROUP,VET_GROUP,FIRMPDEMP&for=us:*&NAICS2017=00&key=b3ba78a4a01bf0ea2af20c82bf42f0e425341ee5'
responsecs = requests.get(urlcs)
csjson = responsecs.json()
csdf = pd.DataFrame(csjson,columns=csjson.pop(0))
csdf
# Out:
#               NAME     GEO_ID        NAICS2017_LABEL  SEX ETH_GROUP  \
# 0    United States  0100000US  Total for all sectors  002       020
# 1    United States  0100000US  Total for all sectors  003       020
# 2    United States  0100000US  Total for all sectors  001       001
# 3    United States  0100000US  Total for all sectors  002       001
# 4    United States  0100000US  Total for all sectors  003       001
# ..             ...        ...                    ...  ...       ...
# 240  United States  0100000US  Total for all sectors  004       001
# 241  United States  0100000US  Total for all sectors  001       020
# 242  United States  0100000US  Total for all sectors  001       028
# 243  United States  0100000US  Total for all sectors  001       029
# 244  United States  0100000US  Total for all sectors  001       001
#
#     RACE_GROUP VET_GROUP FIRMPDEMP NAICS2017 us
# 0           00       001     84496        00  1
# 1           00       001    209426        00  1
# ...

# %%
urlbo = 'https://api.census.gov/data/2018/abscbo?get=NAME,GEO_ID,NAICS2017_LABEL,OWNER_SEX,OWNER_ETH,OWNER_RACE,OWNER_VET,OWNPDEMP&for=us:*&OWNCHAR=CG&NAICS2017=00&QDESC=O02&key=b3ba78a4a01bf0ea2af20c82bf42f0e425341ee5'
responsebo = requests.get(urlbo)
bojson = responsebo.json()
bodf = pd.DataFrame(bojson,columns=bojson.pop(0))
bodf
# Out:
#              NAME     GEO_ID        NAICS2017_LABEL OWNER_SEX OWNER_ETH  \
# 0   United States  0100000US  Total for all sectors       002       001
# 1   United States  0100000US  Total for all sectors       003       001
# 2   United States  0100000US  Total for all sectors       001       001
# 3   United States  0100000US  Total for all sectors       001       001
# 4   United States  0100000US  Total for all sectors       002       001
# 5   United States  0100000US  Total for all sectors       003       001
# 6   United States  0100000US  Total for all sectors       001       020
# 7   United States  0100000US  Total for all sectors       002       020
# 8   United States  0100000US  Total for all sectors       003       020
# 9   United States  0100000US  Total for all sectors       001       029
# 10  United States  0100000US  Total for all sectors       002       029
# 11  United States  0100000US  Total for all sectors       003       029
# ...

# %%
urltcb = 'https://api.census.gov/data/2018/abstcb?get=NAME,GEO_ID,NAICS2017_LABEL,TECHUSE,FIRMPDEMP&for=us:*&NAICS2017=00&key=b3ba78a4a01bf0ea2af20c82bf42f0e425341ee5'
responsetcb = requests.get(urltcb)
tcbjson = responsetcb.json()
tcbdf = pd.DataFrame(tcbjson,columns=tcbjson.pop(0))
tcbdf
# Out:
#              NAME     GEO_ID        NAICS2017_LABEL   TECHUSE FIRMPDEMP  \
# 0   United States  0100000US  Total for all sectors  T1E03B01   4336113
# 1   United States  0100000US  Total for all sectors  T1E03B02     21056
# 2   United States  0100000US  Total for all sectors  T1E03B03     75095
# 3   United States  0100000US  Total for all sectors  T1E03B04     46424
# 4   United States  0100000US  Total for all sectors  T1E03B05     20212
# 5   United States  0100000US  Total for all sectors  T1E03B06    251786
# 6   United States  0100000US  Total for all sectors  T1E03B99    141731
# 7   United States  0100000US  Total for all sectors  T1E03BA9   4750687
# 8   United States  0100000US  Total for all sectors  T2E03B01   2931192
# 9   United States  0100000US  Total for all sectors  T4E03B05     16510
# 10  United States  0100000US  Total for all sectors  T4E03B06    170601
# 11  United States  0100000US  Total for all sectors  T4E03B99     88657
# ...

# %%
#Characteristics of business json

cbdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   NAME             95 non-null     object
#  1   GEO_ID           95 non-null     object
#  2   NAICS2017_LABEL  95 non-null     object
#  3   SEX              95 non-null     object
#  4   ETH_GROUP        95 non-null     object
#  5   RACE_GROUP       95 non-null     object
#  6   VET_GROUP        95 non-null     object
#  7   FIRMPDEMP        95 non-null     object
#  8   NAICS2017        95 non-null     object
#  9   BUSCHAR          95 non-null     object
#  10  QDESC            95 non-null     object
#  11  us               95 non-null     object
# dtypes: object(12)
# memory usage: 9.0+ KB

# %%
viz1 = cbdf[['SEX','RACE_GROUP']]

# %%
cbdf['RACE_GROUP']=cbdf['RACE_GROUP'].astype(object)
bodf['OWNER_RACE']=bodf['OWNER_RACE'].astype(int)

# %%
cbdf['SEX'].hist()
plt.xticks(rotation=0);

# %%
cbdf.head()
# Out:
#             NAME     GEO_ID        NAICS2017_LABEL  SEX ETH_GROUP RACE_GROUP  \
# 0  United States  0100000US  Total for all sectors  1.0       001        0.0
# 1  United States  0100000US  Total for all sectors  2.0       001        0.0
# 2  United States  0100000US  Total for all sectors  3.0       001        0.0
# 3  United States  0100000US  Total for all sectors  4.0       001        0.0
# 4  United States  0100000US  Total for all sectors  1.0       020        0.0
#
#   VET_GROUP FIRMPDEMP NAICS2017 BUSCHAR QDESC us
# 0       001   5722142        00      A1   B01  1
# 1       001   1141410        00      A1   B01  1
# 2       001   3496959        00      A1   B01  1
# 3       001    860754        00      A1   B01  1
# 4       001    331625        00      A1   B01  1

# %%
#Business Owners race group
plt.figure(figsize=(18,8)) 
viz2=bodf['OWNER_RACE']
#cbdf.value_counts()
viz2.plot.bar()
plt.xticks(rotation=90);

# %%
test=csdf['FIRMPDEMP']
test
# Out:
# 0        84496
# 1       209426
# 2      5722142
# 3      1141410
# 4      3496959
#         ...
# 240      84829
# 241       3761
# 242          0
# 243     565167
# 244       6145
# Name: FIRMPDEMP, Length: 245, dtype: object

# %%
csdf.columns
# Out:
# Index(['NAME', 'GEO_ID', 'NAICS2017_LABEL', 'SEX', 'ETH_GROUP', 'RACE_GROUP',
#        'VET_GROUP', 'FIRMPDEMP', 'NAICS2017', 'us'],
#       dtype='object')

# %%
cslist=[]
for i in csdf['FIRMPDEMP']:
    if i ==0 and i <101:
        cslist.append(i)
cslist
# Out:
# []

# %%
ree = cbdf[['SEX','VET_GROUP']]
ree.plot.scatter(x='SEX', y='VET_GROUP', title= " Veteran Status and Sex")
plt.ylim([0,5]) 
plt.xlim([0,5])
# Out:
# (0.0, 5.0)

# %%
lol = csdf[['SEX','FIRMPDEMP']]
lol.plot.scatter(x='FIRMPDEMP', y='SEX', title= " FIRMPDEMP and Sex")
#plt.ylim([0,5]) 
#plt.xlim([0,5]) 
plt.xticks(rotation=90,size=5);
