# %%
import pandas as pd
import numpy as np

df_2008 = pd.read_csv("loans2008.csv")
df_2008.head()
df_2008.drop("_id", axis=1, inplace=True) #removing ID column
df_2008.drop("FEMA Disaster Number", axis=1, inplace=True) #Removing FEMA column
df_2008['Year'] = 2008 #adding year
df_2008.head()
# Out:
#    SBA Physical Declaration Number  SBA EIDL Declaration Number  \
# 0                            11055                        11056
# 1                            11055                        11056
# 2                            11055                        11056
# 3                            11055                        11056
# 4                            11055                        11056
#
#   SBA Disaster Number Damaged Property City Name  Damaged Property Zip Code  \
# 0            TX-00265                     BOERNE                      78006
# 1            TX-00265                CASTROVILLE                      78009
# 2            TX-00265                     HAMLIN                      79520
# 3            TX-00265                    HOUSTON                      77034
# 4            TX-00265                     MERKEL                      79536
#
#   Damaged Property County/Parish Name Damaged Property State Code  \
# 0                             KENDALL                          TX
# 1                              MEDINA                          TX
# 2                               JONES                          TX
# 3                              HARRIS                          TX
# 4                              TAYLOR                          TX
#
#    Total Verified Loss  Verified Loss Real Estate  Verified Loss Content  \
# 0               747912                     747912                      0
# 1               111171                      72946                  38225
# 2                 4235                       4235                      0
# 3                57525                      57525                      0
# 4                87424                      76474                  10950
#
#    Total Approved Loan Amount  Approved Amount Real Estate  \
# 0                           0                            0
# 1                       69700                        26400
# 2                        4300                         4300
# 3                           0                            0
# 4                           0                            0
#
#    Approved Amount Content  Approved Amount EIDL  Year
# 0                        0                     0  2008
# 1                    26700                 16600  2008
# 2                        0                     0  2008
# 3                        0                     0  2008
# 4                        0                     0  2008

# %% [markdown]
# Do cleaning process for each year up until 2015

# %%
df_2009 = pd.read_csv("loans2009.csv")

df_2009.drop("FEMA Disaster Number", axis=1, inplace=True) #Removing FEMA column 
df_2009.drop("_id", axis=1, inplace=True) #Removing ID column
df_2009.dropna()
df_2009['Year']=2009 #adding the year column
df_2009.head()
# Out:
#   SBA Physical Declaration Number  SBA EIDL Declaration Number  \
# 0                           11464                      11465.0
# 1                           11464                      11465.0
# 2                           11464                      11465.0
# 3                           11464                      11465.0
# 4                           11464                      11465.0
#
#   SBA Disaster Number Damaged Property City Name  Damaged Property Zip Code  \
# 0            PR-00003                    AGUIRRE                      704.0
# 1            PR-00003                   AIBONITO                      705.0
# 2            PR-00003                     ARROYO                      714.0
# 3            PR-00003                   BOQUERON                      622.0
# 4            PR-00003                  CABO ROJO                      622.0
#
#   Damaged Property County/Parish Name Damaged Property State Code  \
# 0                             SALINAS                          PR
# 1                            AIBONITO                          PR
# 2                              ARROYO                          PR
# 3                           CABO ROJO                          PR
# 4                           CABO ROJO                          PR
#
#    Total Verified Loss  Verified Loss Real Estate  Verified Loss Content  \
# 0              51165.0                    46475.0                 4690.0
# 1                  0.0                        0.0                    0.0
# 2             116290.0                   100558.0                15732.0
# 3              12454.0                    12454.0                    0.0
# 4              35170.0                    35170.0                    0.0
#
#    Total Approved Loan Amount  Approved Amount Real Estate  \
# 0                         0.0                          0.0
# 1                     12000.0                          0.0
# 2                     21000.0                      19800.0
# 3                      6600.0                       4500.0
# 4                         0.0                          0.0
#
#    Approved Amount Content  Approved Amount EIDL  Year
# 0                      0.0                   0.0  2009
# 1                      0.0               12000.0  2009
# 2                      0.0                1200.0  2009
# 3                      0.0                2100.0  2009
# 4                      0.0                   0.0  2009

# %%
df_2010 = pd.read_csv("loans2010.csv")

df_2010.drop("FEMA Disaster Number", axis=1, inplace=True)
df_2010.drop("_id", axis=1, inplace=True)
df_2010.dropna()

df_2010['Year']=2010
df_2010.head(20)
# Out:
#    SBA Physical Declaration Number  SBA EIDL Declaration Number  \
# 0                            11891                      11892.0
# 1                            11891                      11892.0
# 2                            11909                      11910.0
# 3                            11909                      11910.0
# 4                            11909                      11910.0
# 5                            11909                      11910.0
# 6                            11909                      11910.0
# 7                            11924                      11925.0
# 8                            11926                      11927.0
# 9                            11926                      11927.0
# 10                           11926                      11927.0
# 11                           11926                      11927.0
# 12                           11939                      11940.0
# 13                           11939                      11940.0
# 14                           11939                      11940.0
# 15                           11939                      11940.0
# 16                           11939                      11940.0
# 17                           11939                      11940.0
# 18                           11939                      11940.0
# 19                           11939                      11940.0
#
#    SBA Disaster Number Damaged Property City Name  Damaged Property Zip Code  \
# 0             NY-00074                    YONKERS                    10701.0
# 1             NY-00074                    YONKERS                    10703.0
# 2             TN-00033                CHATTANOOGA                    37404.0
# 3             TN-00033                CHATTANOOGA                    37411.0
# 4             TN-00033                CHATTANOOGA                    37412.0
# 5             TN-00033                CHATTANOOGA                    37415.0
# 6             TN-00033                 EAST RIDGE                    37412.0
# 7             PA-00027                 BLOOMSBURG                    17815.0
# 8             IN-00031                CLARKSVILLE                    47129.0
# 9             IN-00031             JEFFERSONVILLE                    47130.0
# 10            IN-00031                 NEW ALBANY                    47150.0
# 11            IN-00031                SELLERSBURG                    47172.0
# 12            VA-00026                 CHESAPEAKE                    23320.0
# 13            VA-00026                 CHESAPEAKE                    23322.0
# 14            VA-00026                 CHESAPEAKE                    23323.0
# 15            VA-00026                 CHESAPEAKE                    23324.0
# 16            VA-00026                    HAMPTON                    23663.0
# 17            VA-00026                    HAMPTON                    23664.0
# 18            VA-00026                    HAMPTON                    23669.0
# 19            VA-00026               NEWPORT NEWS                    23602.0
#
#    Damaged Property County/Parish Name Damaged Property State Code  \
# 0                          WESTCHESTER                          NY
# 1                          WESTCHESTER                          NY
# 2                             HAMILTON                          TN
# 3                             HAMILTON                          TN
# 4                             HAMILTON                          TN
# 5                             HAMILTON                          TN
# 6                             HAMILTON                          TN
# 7                             COLUMBIA                          PA
# 8                                CLARK                          IN
# 9                                CLARK                          IN
# 10                               FLOYD                          IN
# 11                               CLARK                          IN
# 12                     CHESAPEAKE CITY                          VA
# 13                     CHESAPEAKE CITY                          VA
# 14                     CHESAPEAKE CITY                          VA
# 15                     CHESAPEAKE CITY                          VA
# 16                        HAMPTON CITY                          VA
# 17                        HAMPTON CITY                          VA
# 18                        HAMPTON CITY                          VA
# 19                   NEWPORT NEWS CITY                          VA
#
#     Total Verified Loss  Verified Loss Real Estate  Verified Loss Content  \
# 0              100121.0                    98421.0                 1700.0
# 1               37131.0                    37131.0                    0.0
# 2               22370.0                     8300.0                14070.0
# 3              152597.0                    86888.0                65709.0
# 4             1561422.0                  1054936.0               506486.0
# 5               20768.0                    14768.0                 6000.0
# 6             1020453.0                   956015.0                64438.0
# 7             1376864.0                  1224491.0               152373.0
# 8               53727.0                    53727.0                    0.0
# 9              644524.0                   627452.0                17072.0
# 10              76450.0                    76450.0                    0.0
# 11              32399.0                    32399.0                    0.0
# 12              29073.0                    14766.0                14307.0
# 13             293020.0                   265943.0                27077.0
# 14              40781.0                    40781.0                    0.0
# 15              24328.0                    23578.0                  750.0
# 16              14800.0                    14800.0                    0.0
# 17             113518.0                   113518.0                    0.0
# 18             156641.0                   123665.0                32976.0
# 19               7163.0                     7163.0                    0.0
#
#     Total Approved Loan Amount  Approved Amount Real Estate  \
# 0                      43400.0                      41700.0
# 1                          0.0                          0.0
# 2                      22400.0                       8300.0
# 3                     152600.0                      86900.0
# 4                    1558600.0                     555000.0
# 5                          0.0                          0.0
# 6                      87300.0                          0.0
# 7                     782500.0                     624000.0
# 8                      43800.0                      43800.0
# 9                     177400.0                     110300.0
# 10                         0.0                          0.0
# 11                         0.0                          0.0
# 12                         0.0                          0.0
# 13                    185800.0                     183900.0
# 14                         0.0                          0.0
# 15                         0.0                          0.0
# 16                         0.0                          0.0
# 17                    113600.0                     113600.0
# 18                         0.0                          0.0
# 19                         0.0                          0.0
#
#     Approved Amount Content  Approved Amount EIDL  Year
# 0                    1700.0                   0.0  2010
# 1                       0.0                   0.0  2010
# 2                   14100.0                   0.0  2010
# 3                   65700.0                   0.0  2010
# 4                  506500.0              497100.0  2010
# 5                       0.0                   0.0  2010
# 6                       0.0               87300.0  2010
# 7                  152300.0                6200.0  2010
# 8                       0.0                   0.0  2010
# 9                   17100.0                   0.0  2010
# 10                      0.0                   0.0  2010
# 11                      0.0                   0.0  2010
# 12                      0.0                   0.0  2010
# 13                   1900.0                   0.0  2010
# 14                      0.0                   0.0  2010
# 15                      0.0                   0.0  2010
# 16                      0.0                   0.0  2010
# 17                      0.0                   0.0  2010
# 18                      0.0                   0.0  2010
# 19                      0.0                   0.0  2010

# %%
df_2011 = pd.read_csv("loans2011.csv")

df_2011.drop("FEMA Disaster Number", axis=1, inplace=True)
df_2011.drop("_id", axis=1, inplace=True)
df_2011.dropna()

df_2011['Year']=2011
df_2011.head()
# Out:
#    SBA Physical Declaration Number  SBA EIDL Declaration Number  \
# 0                            12351                        12352
# 1                            12351                        12352
# 2                            12351                        12352
# 3                            12351                        12352
# 4                            12351                        12352
#
#   SBA Disaster Number Damaged Property City Name  Damaged Property Zip Code  \
# 0            MN-00027               DODGE CENTER                      55927
# 1            MN-00027                  FARIBAULT                      55021
# 2            MN-00027                    HAMMOND                      55991
# 3            MN-00027                    MAZEPPA                      55956
# 4            MN-00027                  MILLVILLE                      55957
#
#   Damaged Property County/Parish Name Damaged Property State Code  \
# 0                               DODGE                          MN
# 1                                RICE                          MN
# 2                             WABASHA                          MN
# 3                             WABASHA                          MN
# 4                             WABASHA                          MN
#
#    Total Verified Loss  Verified Loss Real Estate  Verified Loss Content  \
# 0                63022                      47520                  15502
# 1                36153                      34353                   1800
# 2               512397                     400601                 111796
# 3               158937                     142826                  16111
# 4               386098                     379198                   6900
#
#    Total Approved Loan Amount  Approved Amount Real Estate  \
# 0                       14000                        14000
# 1                       26700                        26200
# 2                      499000                       216700
# 3                      158900                       142800
# 4                           0                            0
#
#    Approved Amount Content  Approved Amount EIDL  Year
# 0                        0                     0  2011
# 1                      500                     0  2011
# 2                    98600                 26000  2011
# 3                    16100                     0  2011
# 4                        0                     0  2011

# %%
df_2012 = pd.read_csv("loans2012.csv")

df_2012.drop("FEMA Disaster Number", axis=1, inplace=True)
df_2012.drop("_id", axis=1, inplace=True)
df_2012.dropna()

df_2012['Year']=2012
df_2012.head()
# Out:
#   SBA Physical Declaration Number  SBA EIDL Declaration Number  \
# 0                           12876                      12877.0
# 1                           12884                      12885.0
# 2                           12884                      12885.0
# 3                           12884                      12885.0
# 4                           12884                      12885.0
#
#   SBA Disaster Number Damaged Property City Name  Damaged Property Zip Code  \
# 0            NJ-00022               PHILADELPHIA                    19132.0
# 1            MA-00043                    BEVERLY                     1915.0
# 2            MA-00043                       LYNN                     1901.0
# 3            MA-00043                       LYNN                     1902.0
# 4            MA-00043                 SWAMPSCOTT                     1907.0
#
#   Damaged Property County/Parish Name Damaged Property State Code  \
# 0                        PHILADELPHIA                          PA
# 1                               ESSEX                          MA
# 2                               ESSEX                          MA
# 3                               ESSEX                          MA
# 4                               ESSEX                          MA
#
#    Total Verified Loss  Verified Loss Real Estate  Verified Loss Content  \
# 0              38232.0                    38232.0                    0.0
# 1             299066.0                   140296.0               158770.0
# 2             254946.0                   189991.0                64955.0
# 3              37129.0                     5179.0                31950.0
# 4              36836.0                    23336.0                13500.0
#
#    Total Approved Loan Amount  Approved Amount Real Estate  \
# 0                         0.0                          0.0
# 1                    263800.0                      25600.0
# 2                         0.0                          0.0
# 3                     32000.0                          0.0
# 4                     34100.0                      16900.0
#
#    Approved Amount Content  Approved Amount EIDL  Year
# 0                      0.0                   0.0  2012
# 1                 150600.0               87600.0  2012
# 2                      0.0                   0.0  2012
# 3                  32000.0                   0.0  2012
# 4                  13500.0                3700.0  2012

# %%
df_2013 = pd.read_csv("loans2013.csv")

df_2013.drop("FEMA Disaster Number", axis=1, inplace=True)
df_2013.drop("_id", axis=1, inplace=True)
df_2013.dropna()

df_2013['Year']=2013
df_2013.head()
# Out:
#    SBA Physical Declaration Number  SBA EIDL Declaration Number  \
# 0                            13326                        13327
# 1                            13328                        13329
# 2                            13330                        13331
# 3                            13341                        13342
# 4                            13346                        13347
#
#   SBA Disaster Number Damaged Property City Name  Damaged Property Zip Code  \
# 0            UT-00015                SANTA CLARA                      84765
# 1            OK-00066                     LUTHER                      73054
# 2            OK-00067                    GLENCOE                      74032
# 3            NY-00126                     BETHEL                      12720
# 4            PA-00054                    WYNCOTE                      19095
#
#   Damaged Property County/Parish Name Damaged Property State Code  \
# 0                          WASHINGTON                          UT
# 1                            OKLAHOMA                          OK
# 2                               PAYNE                          OK
# 3                            SULLIVAN                          NY
# 4                          MONTGOMERY                          PA
#
#    Total Verified Loss  Verified Loss Real Estate  Verified Loss Content  \
# 0               514761                     387766                 126995
# 1                61759                      32029                  29730
# 2                75248                      30758                  44490
# 3                17331                      17331                      0
# 4               102761                      83586                  19175
#
#    Total Approved Loan Amount  Approved Amount Real Estate  \
# 0                      160600                     158900.0
# 1                           0                          0.0
# 2                       77200                      30800.0
# 3                           0                          0.0
# 4                       28900                      21800.0
#
#    Approved Amount Content  Approved Amount EIDL  Year
# 0                   1700.0                     0  2013
# 1                      0.0                     0  2013
# 2                  44500.0                  1900  2013
# 3                      0.0                     0  2013
# 4                   6000.0                  1100  2013

# %%
df_2014 = pd.read_csv("loans2014.csv")

df_2014.drop("FEMA Disaster Number", axis=1, inplace=True)
df_2014.drop("_id", axis=1, inplace=True)
df_2014.dropna()

df_2014['Year']=2014
df_2014.head()
# Out:
#   SBA Physical Declaration Number  SBA EIDL Declaration Number  \
# 0                           13792                      13793.0
# 1                           13794                      13795.0
# 2                           13794                      13795.0
# 3                           13794                      13795.0
# 4                           13794                      13795.0
#
#   SBA Disaster Number Damaged Property City Name  Damaged Property Zip Code  \
# 0            SC-00024                 GEORGETOWN                    29440.0
# 1            MO-00067                BULL SHOALS                    72619.0
# 2            MO-00067               DEVILS ELBOW                    65457.0
# 3            MO-00067                     LAQUEY                    65534.0
# 4            MO-00067                   RICHLAND                    65556.0
#
#   Damaged Property County/Parish Name Damaged Property State Code  \
# 0                          GEORGETOWN                          SC
# 1                              MARION                          AR
# 2                             PULASKI                          MO
# 3                             PULASKI                          MO
# 4                             PULASKI                          MO
#
#    Total Verified Loss  Verified Loss Real Estate  Verified Loss Content  \
# 0             749971.0                    61233.0               688738.0
# 1                  0.0                        0.0                    0.0
# 2              12675.0                    12675.0                    0.0
# 3               4510.0                        0.0                 4510.0
# 4              42550.0                    28515.0                14035.0
#
#    Total Approved Loan Amount  Approved Amount Real Estate  \
# 0                    509500.0                      31800.0
# 1                      5000.0                          0.0
# 2                         0.0                          0.0
# 3                         0.0                          0.0
# 4                         0.0                          0.0
#
#    Approved Amount Content  Approved Amount EIDL  Year
# 0                 399000.0               78700.0  2014
# 1                      0.0                5000.0  2014
# 2                      0.0                   0.0  2014
# 3                      0.0                   0.0  2014
# 4                      0.0                   0.0  2014

# %%
df_2015 = pd.read_csv("loans2015.csv")

df_2015.drop("FEMA Disaster Number", axis=1, inplace=True)
df_2015.drop("_id", axis=1, inplace=True)
df_2015.dropna()

df_2015['Year']=2015
df_2015.head()
# Out:
#    SBA Physical Declaration Number  SBA EIDL Declaration Number  \
# 0                            14138                        14139
# 1                            14143                        14144
# 2                            14143                        14144
# 3                            14143                        14144
# 4                            14143                        14144
#
#   SBA Disaster Number Damaged Property City Name Damaged Property Zip Code  \
# 0            CA-00225                       WEED                     96094
# 1            AZ-00039                   GLENDALE                     85301
# 2            AZ-00039                       MESA                     85204
# 3            AZ-00039                       MESA                     85210
# 4            AZ-00039                       MESA                     85213
#
#   Damaged Property County/Parish Name Damaged Property State Code  \
# 0                            SISKIYOU                          CA
# 1                            MARICOPA                          AZ
# 2                            MARICOPA                          AZ
# 3                            MARICOPA                          AZ
# 4                            MARICOPA                          AZ
#
#    Total Verified Loss  Verified Loss Real Estate  Verified Loss Content  \
# 0              1175762                    1145392                  30370
# 1                88454                      88454                      0
# 2                19033                      19033                      0
# 3                 9878                       5978                   3900
# 4                88971                      88971                      0
#
#    Total Approved Loan Amount  Approved Amount Real Estate  \
# 0                       95000                        51200
# 1                       99100                        88500
# 2                       19100                        19100
# 3                           0                            0
# 4                       89000                        89000
#
#    Approved Amount Content  Approved Amount EIDL  Year
# 0                        0               43800.0  2015
# 1                        0               10600.0  2015
# 2                        0                   0.0  2015
# 3                        0                   0.0  2015
# 4                        0                   0.0  2015

# %% [markdown]
# Adding data from every year to the same dataframe

# %%
df_all = df_2008.append(df_2009, ignore_index = True)

df_all = df_all.append(df_2010, ignore_index = True)

df_all = df_all.append(df_2011, ignore_index = True)

df_all = df_all.append(df_2012, ignore_index = True)

df_all = df_all.append(df_2013, ignore_index = True)

df_all = df_all.append(df_2014, ignore_index = True)

df_all = df_all.append(df_2015, ignore_index = True)

df_all.Year.unique()

df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8648 entries, 0 to 8647
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   SBA Physical Declaration Number      8648 non-null   object
#  1   SBA EIDL Declaration Number          8640 non-null   float64
#  2   SBA Disaster Number                  8640 non-null   object
#  3   Damaged Property City Name           8640 non-null   object
#  4   Damaged Property Zip Code            8640 non-null   object
#  5   Damaged Property County/Parish Name  8640 non-null   object
#  6   Damaged Property State Code          8640 non-null   object
#  7   Total Verified Loss                  8640 non-null   float64
#  8   Verified Loss Real Estate            8640 non-null   float64
#  9   Verified Loss Content                8640 non-null   float64
#  10  Total Approved Loan Amount           8640 non-null   float64
#  11  Approved Amount Real Estate          8640 non-null   float64
#  12  Approved Amount Content              8640 non-null   float64
#  13  Approved Amount EIDL                 8606 non-null   float64
#  14  Year                                 8648 non-null   int64
# dtypes: float64(8), int64(1), object(6)
# memory usage: 1013.6+ KB

# %%
df_all.head()
# Out:
#   SBA Physical Declaration Number  SBA EIDL Declaration Number  \
# 0                           11055                      11056.0
# 1                           11055                      11056.0
# 2                           11055                      11056.0
# 3                           11055                      11056.0
# 4                           11055                      11056.0
#
#   SBA Disaster Number Damaged Property City Name Damaged Property Zip Code  \
# 0            TX-00265                     BOERNE                   78006.0
# 1            TX-00265                CASTROVILLE                   78009.0
# 2            TX-00265                     HAMLIN                   79520.0
# 3            TX-00265                    HOUSTON                   77034.0
# 4            TX-00265                     MERKEL                   79536.0
#
#   Damaged Property County/Parish Name Damaged Property State Code  \
# 0                             KENDALL                          TX
# 1                              MEDINA                          TX
# 2                               JONES                          TX
# 3                              HARRIS                          TX
# 4                              TAYLOR                          TX
#
#    Total Verified Loss  Verified Loss Real Estate  Verified Loss Content  \
# 0             747912.0                   747912.0                    0.0
# 1             111171.0                    72946.0                38225.0
# 2               4235.0                     4235.0                    0.0
# 3              57525.0                    57525.0                    0.0
# 4              87424.0                    76474.0                10950.0
#
#    Total Approved Loan Amount  Approved Amount Real Estate  \
# 0                         0.0                          0.0
# 1                     69700.0                      26400.0
# 2                      4300.0                       4300.0
# 3                         0.0                          0.0
# 4                         0.0                          0.0
#
#    Approved Amount Content  Approved Amount EIDL  Year
# 0                      0.0                   0.0  2008
# 1                  26700.0               16600.0  2008
# 2                      0.0                   0.0  2008
# 3                      0.0                   0.0  2008
# 4                      0.0                   0.0  2008

# %%
df_all.head()
# Out:
#   SBA Physical Declaration Number  SBA EIDL Declaration Number  \
# 0                           11055                      11056.0
# 1                           11055                      11056.0
# 2                           11055                      11056.0
# 3                           11055                      11056.0
# 4                           11055                      11056.0
#
#   SBA Disaster Number Damaged Property City Name Damaged Property Zip Code  \
# 0            TX-00265                     BOERNE                   78006.0
# 1            TX-00265                CASTROVILLE                   78009.0
# 2            TX-00265                     HAMLIN                   79520.0
# 3            TX-00265                    HOUSTON                   77034.0
# 4            TX-00265                     MERKEL                   79536.0
#
#   Damaged Property County/Parish Name Damaged Property State Code  \
# 0                             KENDALL                          TX
# 1                              MEDINA                          TX
# 2                               JONES                          TX
# 3                              HARRIS                          TX
# 4                              TAYLOR                          TX
#
#    Total Verified Loss  Verified Loss Real Estate  Verified Loss Content  \
# 0             747912.0                   747912.0                    0.0
# 1             111171.0                    72946.0                38225.0
# 2               4235.0                     4235.0                    0.0
# 3              57525.0                    57525.0                    0.0
# 4              87424.0                    76474.0                10950.0
#
#    Total Approved Loan Amount  Approved Amount Real Estate  \
# 0                         0.0                          0.0
# 1                     69700.0                      26400.0
# 2                      4300.0                       4300.0
# 3                         0.0                          0.0
# 4                         0.0                          0.0
#
#    Approved Amount Content  Approved Amount EIDL  Year
# 0                      0.0                   0.0  2008
# 1                  26700.0               16600.0  2008
# 2                      0.0                   0.0  2008
# 3                      0.0                   0.0  2008
# 4                      0.0                   0.0  2008

# %%
df_all.isnull().sum()
# Out:
# SBA Physical Declaration Number         0
# SBA EIDL Declaration Number             8
# SBA Disaster Number                     8
# Damaged Property City Name              8
# Damaged Property Zip Code               8
# Damaged Property County/Parish Name     8
# Damaged Property State Code             8
# Total Verified Loss                     8
# Verified Loss Real Estate               8
# Verified Loss Content                   8
# Total Approved Loan Amount              8
# Approved Amount Real Estate             8
# Approved Amount Content                 8
# Approved Amount EIDL                   42
# Year                                    0
# dtype: int64

# %% [markdown]
# Adding a dataframe for the full state names so we can join on State Names later

# %%
States = pd.read_csv("states.csv")

# %%
df_all.dropna(axis=0, inplace=True)

# %%
States.head()
# Out:
#         State  Abbrev Code
# 0     Alabama    Ala.   AL
# 1      Alaska  Alaska   AK
# 2     Arizona   Ariz.   AZ
# 3    Arkansas    Ark.   AR
# 4  California  Calif.   CA

# %%
States = States.rename(columns={'Code': 'State Code'})

# %%
df_all = df_all.rename(columns={'Damaged Property State Code': 'State Code'})

# %%
madf = df_all.merge(States, on='State Code', how='inner')

madf.drop("State Code", axis=1, inplace=True)
madf.drop("Abbrev", axis=1, inplace=True)

# %%
madf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8395 entries, 0 to 8394
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   SBA Physical Declaration Number      8395 non-null   object
#  1   SBA EIDL Declaration Number          8395 non-null   float64
#  2   SBA Disaster Number                  8395 non-null   object
#  3   Damaged Property City Name           8395 non-null   object
#  4   Damaged Property Zip Code            8395 non-null   object
#  5   Damaged Property County/Parish Name  8395 non-null   object
#  6   Total Verified Loss                  8395 non-null   float64
#  7   Verified Loss Real Estate            8395 non-null   float64
#  8   Verified Loss Content                8395 non-null   float64
#  9   Total Approved Loan Amount           8395 non-null   float64
#  10  Approved Amount Real Estate          8395 non-null   float64
#  11  Approved Amount Content              8395 non-null   float64
#  12  Approved Amount EIDL                 8395 non-null   float64
#  13  Year                                 8395 non-null   int64
#  14  State                                8395 non-null   object
# dtypes: float64(8), int64(1), object(6)
# memory usage: 1.0+ MB

# %%
madf.head()
# Out:
#   SBA Physical Declaration Number  SBA EIDL Declaration Number  \
# 0                           11055                      11056.0
# 1                           11055                      11056.0
# 2                           11055                      11056.0
# 3                           11055                      11056.0
# 4                           11055                      11056.0
#
#   SBA Disaster Number Damaged Property City Name Damaged Property Zip Code  \
# 0            TX-00265                     BOERNE                   78006.0
# 1            TX-00265                CASTROVILLE                   78009.0
# 2            TX-00265                     HAMLIN                   79520.0
# 3            TX-00265                    HOUSTON                   77034.0
# 4            TX-00265                     MERKEL                   79536.0
#
#   Damaged Property County/Parish Name  Total Verified Loss  \
# 0                             KENDALL             747912.0
# 1                              MEDINA             111171.0
# 2                               JONES               4235.0
# 3                              HARRIS              57525.0
# 4                              TAYLOR              87424.0
#
#    Verified Loss Real Estate  Verified Loss Content  \
# 0                   747912.0                    0.0
# 1                    72946.0                38225.0
# 2                     4235.0                    0.0
# 3                    57525.0                    0.0
# 4                    76474.0                10950.0
#
#    Total Approved Loan Amount  Approved Amount Real Estate  \
# 0                         0.0                          0.0
# 1                     69700.0                      26400.0
# 2                      4300.0                       4300.0
# 3                         0.0                          0.0
# 4                         0.0                          0.0
#
#    Approved Amount Content  Approved Amount EIDL  Year  State
# 0                      0.0                   0.0  2008  Texas
# 1                  26700.0               16600.0  2008  Texas
# 2                      0.0                   0.0  2008  Texas
# 3                      0.0                   0.0  2008  Texas
# 4                      0.0                   0.0  2008  Texas

# %%
madf.to_csv(r'C:\Dev10\Assessments\mikhaela-capstone\full-disaster-loan.csv', index=False)
